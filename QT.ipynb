# %% [markdown]
# ## Build Back Testing
# Follow the buy and sell decisions from both the retail investors or the institution investors as per fund flow data provided, build two trading strategies Smart Retail Flow FT5009 and Smart Insti Flow FT5009. That is, you buy and sell the same stocks as retail investors or institutional investors from the fund flow report.
#
# The strategy Smart Retail Flow FT5009 strictly follows the weekly buy sell decisions of retail investors and the strategy Smart Insti Flow FT5009 strictly follows the weekly buy sell decisions of institution investors.
# - Prepare the return of the stocks (1%)
# - Identify the position of stocks to buy and sell (2%)

# %% [markdown]
# close or open

# %%
import pandas as pd
import numpy as np

top_stocks_path = './data/data.csv'
stock_prices_path = './data/stock.csv'
# 读取模拟的资金流数据
top_stocks_data = pd.read_csv(top_stocks_path)
stock_prices_data = pd.read_csv(stock_prices_path)
# stock_prices_data['Open Return'] = stock_prices_data.groupby('Stock Code')['Open'].pct_change()
PRICE = 'Open'

# 假设初始资金和相关参数
initial_capital = 1_000_000  # 初始资金1M
min_trade_units = 100        # 最小购买单位 100股
holding_period_limit = 4     # 最长持仓4周
borrow_cost_rate = 0.001     # 借贷利率 0.1%
weekly_capital_interval = 4  # 每四周重新计算交易资金
borrow_cash = 100_000        # 每次借贷现金 10w

# 创建两个策略组合
portfolio_retail = {}
portfolio_institution = {}

# 设置回测的日期和股票代码信息
dates = top_stocks_data['Date'].unique()

# 初始化组合
portfolio_retail[dates[0]] = {
    'cash': initial_capital,
    'short_sell_cash': 0, # 卖空的现金是锁定的，即每周的交易资金为cash的1/4，不带卖空的现金
    'position_units': {},
    'holding_weeks': {},
    'net_value': 0,
    'borrow_cash': 0,
}
portfolio_institution[dates[0]] = {
    'cash': initial_capital,
    'short_sell_cash': 0,
    'position_units': {},
    'holding_weeks': {},
    'net_value': 0,
    'borrow_cash': 0,
}

# 逐周执行买卖决策
for i, date in enumerate(dates):
    print(f"第{i+1}周：{date}")

    # 获取零售和机构的买卖信号
    retail_signals = top_stocks_data[(top_stocks_data['Date'] == date) & (top_stocks_data['Investor Type'] == 'retail')]
    insti_signals = top_stocks_data[(top_stocks_data['Date'] == date) & (top_stocks_data['Investor Type'] == 'institution')]

    # 处理每个策略的买卖信号
    for strategy, signals, portfolio in zip(
            ['Smart Retail Flow FT5009', 'Smart Insti Flow FT5009'],
            [retail_signals, insti_signals],
            [portfolio_retail, portfolio_institution]):
        
        # signals中的Stock Code在stock_prices_data中可能不存在，需要过滤掉
        signals = signals[signals['Stock Code'].isin(stock_prices_data['Stock Code'])]

        # 获取当前日期的组合
        if i > 0:
            # 复制上周的组合状态
            portfolio[date] = portfolio[dates[i-1]].copy()
        
        current_portfolio = portfolio[date]
        
        current_portfolio['net_value'] = 0  # 重置净值

        # 先花钱将卖空仓位的股票买回，并计算借贷成本（这一步可能造成short_sell_cash<0，因为强制一周时间就仓位归0，此时股价可能比short sell时更贵，低价卖出高价买入造成亏损，再加上借贷成本就更亏了）
        for stock_code, units in list(current_portfolio['position_units'].items()):
            if units < 0:  # 只有卖空仓位才计算借贷成本
                if stock_prices_data[(stock_prices_data['Date'] == dates[i - 1]) & (stock_prices_data['Stock Code'] == stock_code)].shape[0] > 0:  # 确保有上一周的数据
                    prev_date = dates[i - 1]
                    prev_price = stock_prices_data[(stock_prices_data['Date'] == prev_date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
                else:
                    prev_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
                cur_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
                avg_price = (prev_price + cur_price) / 2
                borrow_cost = abs(units) * avg_price * borrow_cost_rate
                current_portfolio['cash'] -= borrow_cost
                current_portfolio['short_sell_cash'] -= abs(units) * cur_price
                del current_portfolio['position_units'][stock_code]  # 清零卖空持仓

        # 如果short sell亏损，则将亏损的short sell用现金补上
        if current_portfolio['short_sell_cash'] < 0:
            current_portfolio['cash'] += current_portfolio['short_sell_cash']
            current_portfolio['short_sell_cash'] = 0


        if current_portfolio['cash'] < 0:
            # 如果现金不足，需要借贷(暂不考虑借贷利息)
            while current_portfolio['cash'] < 0:
                current_portfolio['cash'] += borrow_cash
                current_portfolio['borrow_cash'] += borrow_cash


        # 每周交易资金为总资金的1/4，每四周重新计算
        if i % weekly_capital_interval == 0:
            weekly_capital = current_portfolio['cash'] / weekly_capital_interval


        # 当现金不足时，卖出仓位最小的持仓，直到有足够的现金（>weekly_capital)，保证每周交易资金充足
        while current_portfolio['cash'] < weekly_capital:
            # 如果没有持仓，直接跳出
            if len(current_portfolio['position_units']) == 0:
                break
            # 卖出持仓最小的股票
            stock_code = min(current_portfolio['position_units'], key=current_portfolio['position_units'].get)
            units = current_portfolio['position_units'][stock_code]
            try:
                stock_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
            except:
                print(date, stock_code)
                ii = i
                tmp_date = dates[ii]
                while stock_prices_data[(stock_prices_data['Date'] == tmp_date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].shape[0] == 0:
                    ii -= 1
                    tmp_date = dates[ii]
                stock_price = stock_prices_data[(stock_prices_data['Date'] == tmp_date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]                    
            
            # stock_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
            sell_units = min(min_trade_units, abs(units))
            current_portfolio['cash'] += sell_units * stock_price
            current_portfolio['position_units'][stock_code] -= sell_units
            if current_portfolio['position_units'][stock_code] == 0:
                del current_portfolio['position_units'][stock_code]
                del current_portfolio['holding_weeks'][stock_code]
            else:
                # 不必更新持有时间，因为这只是为了弥补现金不足 
                pass


        # 分别计算买入和卖出的信号强度
        buy_signals = signals[signals['Action'] == 'buy']
        sell_signals = signals[signals['Action'] == 'sell']
        buy_signal_strength = buy_signals['Amount'].abs().sum()
        sell_signal_strength = sell_signals['Amount'].abs().sum()

        # 处理买入信号
        for _, signal in buy_signals.iterrows():
            stock_code = signal['Stock Code']
            amount = abs(signal['Amount'])
            signal_strength = amount / buy_signal_strength  # 买入信号强度

            trade_value = weekly_capital * signal_strength
            # 获取股票价格
            stock_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
            units = int(trade_value / stock_price / min_trade_units) * min_trade_units

            # 扩大持仓并记录持有时间
            if units > 0:
                total_cost = units * stock_price
                current_portfolio['cash'] -= total_cost
                current_portfolio['position_units'][stock_code] = current_portfolio['position_units'].get(stock_code, 0) + units
                current_portfolio['holding_weeks'][stock_code] = 1  # 重置持有时间
            # print('买了',units,'个: ', stock_code, current_portfolio)

        # 处理卖出信号
        for _, signal in sell_signals.iterrows():
            stock_code = signal['Stock Code']
            amount = abs(signal['Amount'])
            signal_strength = amount / sell_signal_strength  # 卖出信号强度

            trade_value = weekly_capital * signal_strength
            # 获取股票价格
            stock_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
            units = int(trade_value / stock_price / min_trade_units) * min_trade_units

            if units > 0:
                # 检查是否有持仓
                held_units = current_portfolio['position_units'].get(stock_code, 0)
                if held_units > 0:
                    # 先卖出持仓部分
                    sell_units = min(units, held_units)
                    current_portfolio['cash'] += sell_units * stock_price
                    current_portfolio['position_units'][stock_code] -= sell_units
                    if current_portfolio['position_units'][stock_code] == 0:
                        del current_portfolio['position_units'][stock_code]
                        del current_portfolio['holding_weeks'][stock_code]
                    else:
                        current_portfolio['holding_weeks'][stock_code] += 1
                   
                    # 剩余部分按short sell处理
                    if sell_units < units:
                        short_units = units - sell_units
                        current_portfolio['short_sell_cash'] += short_units * stock_price  # short sell收益计入现金
                        current_portfolio['position_units'][stock_code] = current_portfolio['position_units'].get(stock_code, 0) - short_units

                else:
                    # 没有持仓时执行short sell
                    current_portfolio['short_sell_cash'] += units * stock_price
                    current_portfolio['position_units'][stock_code] = current_portfolio['position_units'].get(stock_code, 0) - units
            # print('卖了',units,'个: ', stock_code, current_portfolio)

        # 更新持仓时间
        for stock_code in current_portfolio['position_units']:
            if stock_code not in buy_signals['Stock Code'].values and stock_code not in sell_signals['Stock Code'].values:
                current_portfolio['holding_weeks'][stock_code] += 1

        # 清理超过持仓期限的股票
        for stock_code, weeks in list(current_portfolio['holding_weeks'].items()):
            if weeks >= holding_period_limit:
                # 超过持仓期限，强制卖出剩余持仓
                units = current_portfolio['position_units'][stock_code]
                stock_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
                current_portfolio['cash'] += units * stock_price  # 卖出持仓

                del current_portfolio['position_units'][stock_code]
                del current_portfolio['holding_weeks'][stock_code]


        # 假设现在把所有的股票都换成现金，那么净值计算如下
        for stock_code, units in list(current_portfolio['position_units'].items()):
            stock_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
            if units < 0:
                # 确保有上一周的数据
                if stock_prices_data[(stock_prices_data['Date'] == dates[i - 1]) & (stock_prices_data['Stock Code'] == stock_code)].shape[0] > 0:
                    prev_date = dates[i - 1]
                    prev_price = stock_prices_data[(stock_prices_data['Date'] == prev_date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
                else:
                    prev_price = stock_prices_data[(stock_prices_data['Date'] == date) & (stock_prices_data['Stock Code'] == stock_code)][PRICE].values[0]
                avg_price = (prev_price + stock_price) / 2
                current_portfolio['net_value'] += units * avg_price * borrow_cost_rate

            current_portfolio['net_value'] += units * stock_price

        current_portfolio['net_value'] += (current_portfolio['cash'] + current_portfolio['short_sell_cash'] - current_portfolio['borrow_cash'])
        
        print(f"{strategy} Portfolio cash: {current_portfolio['cash']:.2f}, short_sell_cash: {current_portfolio['short_sell_cash']:.2f}, borrow_cash: {current_portfolio['borrow_cash']:.2f}, net_value: {current_portfolio['net_value']:.2f}")
        # 格式化输出持仓为正和负的股票
        positive_positions = {k: v for k, v in current_portfolio['position_units'].items() if v > 0}
        negative_positions = {k: v for k, v in current_portfolio['position_units'].items() if v < 0}

        positive_df = pd.DataFrame(list(positive_positions.items()), columns=['Stock Code', 'Positive Units'])
        negative_df = pd.DataFrame(list(negative_positions.items()), columns=['Stock Code', 'Negative Units'])

        # 合并两个 DataFrame
        merged_df = pd.merge(positive_df, negative_df, on='Stock Code', how='outer')

        # 填充 NaN 值为 0
        merged_df = merged_df.fillna(np.nan)

        # 格式化输出
        print("Combined Positions:")
        print(merged_df.to_string(index=False))
        print()
       
print("Retail Portfolio Final:", portfolio_retail[dates[-1]])
print("Institution Portfolio Final:", portfolio_institution[dates[-1]])
# Out:
# 第1周：2019-01-07
# Smart Retail Flow FT5009 Portfolio cash: 750604.09, short_sell_cash: 245325.12, borrow_cash: 0.00, net_value: 998362.18
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        544         27600.0             NaN
#        5CP         56800.0             NaN
#        BDX        449900.0             NaN
#        BN4             NaN         -5100.0
#        C09             NaN         -2400.0
#       C38U         12600.0             NaN
#        CC3         11300.0             NaN
#       CJLU         22900.0             NaN
#        D05             NaN         -3400.0
#        G13             NaN        -15400.0
#        H02          1200.0             NaN
#        O39             NaN         -6900.0
#        U11             NaN         -1900.0
#        V03             NaN         -1400.0
#        Y92             NaN      -4825600.0
#        Z74             NaN         -7800.0
#
# Smart Insti Flow FT5009 Portfolio cash: 752916.25, short_sell_cash: 249125.05, borrow_cash: 0.00, net_value: 999780.14
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        544             NaN        -24100.0
#        5CP             NaN        -44500.0
#        BDX             NaN       -341700.0
#        C09          1900.0             NaN
#       C38U             NaN        -25300.0
#        C52             NaN        -18300.0
#        CC3             NaN         -9500.0
#       CJLU             NaN        -14400.0
#        D05          3800.0             NaN
#        G13         18300.0             NaN
#        H02             NaN          -900.0
#        O39          4700.0             NaN
#        S58          3100.0             NaN
#        U11          2500.0             NaN
#        V03          1900.0             NaN
#        Y92       7230800.0             NaN
#        Z74          4200.0             NaN
#
# 第2周：2019-01-14
# Smart Retail Flow FT5009 Portfolio cash: 492461.49, short_sell_cash: 247988.03, borrow_cash: 0.00, net_value: 974305.01
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        544         27600.0             NaN
#        5CP         56800.0             NaN
#        BDX        449900.0             NaN
#        BS6             NaN        -37300.0
#       C38U         30500.0             NaN
#        C52         17300.0             NaN
#        C76          5400.0             NaN
#        CC3         32600.0             NaN
#       CJLU         22900.0             NaN
#        D05             NaN         -3100.0
#        G13             NaN        -28400.0
#        H02          1200.0             NaN
#        J36           600.0             NaN
#        O39             NaN         -4900.0
#        S63             NaN         -7300.0
#        S68             NaN         -3800.0
#        U11             NaN         -1400.0
#        U96         63400.0             NaN
#        Y92             NaN      -5818900.0
#        Z25         25300.0             NaN
#        Z74             NaN         -6900.0
#
# Smart Insti Flow FT5009 Portfolio cash: 543683.49, short_sell_cash: 221782.93, borrow_cash: 0.00, net_value: 1023101.65
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U             NaN        -43800.0
#        BS6         64300.0             NaN
#        C09          4200.0             NaN
#       C38U             NaN        -16300.0
#        C52             NaN        -19800.0
#        D05          3800.0             NaN
#        G13         72300.0             NaN
#        H78          2600.0             NaN
#        J36             NaN          -300.0
#        O39          6200.0             NaN
#        S58             NaN         -2200.0
#        S63         12900.0             NaN
#        S68          4800.0             NaN
#        U11          1800.0             NaN
#        U14          2400.0             NaN
#        U96             NaN        -27500.0
#        V03          1900.0             NaN
#        Y92      19272800.0             NaN
#        Z74             NaN         -1700.0
#
# 第3周：2019-01-21
# Smart Retail Flow FT5009 Portfolio cash: 269971.22, short_sell_cash: 217507.74, borrow_cash: 0.00, net_value: 964191.50
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        544         27600.0             NaN
#        5CP         56800.0             NaN
#        BDX        449900.0             NaN
#        BN4         12200.0             NaN
#        BS6             NaN        -23300.0
#       C38U         30500.0             NaN
#        C52             NaN         -5600.0
#        C6L             NaN         -2700.0
#        C76          5400.0             NaN
#        CC3         32600.0             NaN
#       CJLU         22900.0             NaN
#        D05          7500.0             NaN
#        F34             NaN         -5100.0
#        G13         12300.0             NaN
#        H02          1200.0             NaN
#        J36           600.0             NaN
#       K71U          7200.0             NaN
#       M44U             NaN        -12700.0
#        O39          3600.0             NaN
#        S68             NaN        -11900.0
#       T82U             NaN         -9900.0
#        U11           500.0             NaN
#        U96         79500.0             NaN
#        V03             NaN         -3500.0
#        Y92             NaN      -7213000.0
#        Z25         25300.0             NaN
#        Z74          3100.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 440485.22, short_sell_cash: 112052.46, borrow_cash: 0.00, net_value: 1035634.73
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U             NaN         -6900.0
#        BN4             NaN         -8400.0
#        BS6         94100.0             NaN
#        C09          6500.0             NaN
#       C38U          6600.0             NaN
#        C52         39500.0             NaN
#        D05             NaN         -1500.0
#        G13         59400.0             NaN
#        H78          2600.0             NaN
#        O39          2300.0             NaN
#        S63         12900.0             NaN
#        S68         17500.0             NaN
#        U11             NaN          -400.0
#        U14          2400.0             NaN
#        U96             NaN        -11000.0
#        V03          4500.0             NaN
#        Y92      26490100.0             NaN
#        Z74             NaN         -6500.0
#
# 第4周：2019-01-28
# Smart Retail Flow FT5009 Portfolio cash: 220402.18, short_sell_cash: 238725.09, borrow_cash: 0.00, net_value: 950839.02
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN4         38800.0             NaN
#        BS6             NaN        -82000.0
#       C38U         30500.0             NaN
#        C52             NaN        -11400.0
#        C76          5400.0             NaN
#        CC3         32600.0             NaN
#        D05         12300.0             NaN
#        E5H         28300.0             NaN
#        G13             NaN        -24000.0
#        J36           600.0             NaN
#       K71U          7200.0             NaN
#        O39          4800.0             NaN
#        S63             NaN         -9800.0
#        S68             NaN        -16700.0
#        U11          2600.0             NaN
#        U96         91200.0             NaN
#        Y92             NaN      -5544700.0
#        Z25         25300.0             NaN
#        Z59         14200.0             NaN
#        Z74         10500.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 212125.20, short_sell_cash: 240460.18, borrow_cash: 0.00, net_value: 1045421.87
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN4             NaN        -13600.0
#        BS6        213300.0             NaN
#       BUOU         21900.0             NaN
#        C09          6500.0             NaN
#       C38U         18700.0             NaN
#        C52         49100.0             NaN
#        C6L             NaN         -1300.0
#        D05             NaN         -4600.0
#        G13         78900.0             NaN
#        H78          2600.0             NaN
#        O39          1200.0             NaN
#        S63         12900.0             NaN
#        S68         32200.0             NaN
#        U11             NaN         -3100.0
#        U14          1600.0             NaN
#        U96             NaN         -9600.0
#        V03          3900.0             NaN
#        Y92      32163600.0             NaN
#        Z74             NaN        -13300.0
#
# 第5周：2019-02-04
# Smart Retail Flow FT5009 Portfolio cash: 366306.00, short_sell_cash: 21172.29, borrow_cash: 0.00, net_value: 932822.04
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN4         44700.0             NaN
#        BS6             NaN         -8100.0
#        C52          1400.0             NaN
#        D05         11800.0             NaN
#        E5H         28300.0             NaN
#        G13             NaN         -6500.0
#       K71U          1900.0             NaN
#        O39          5000.0             NaN
#        S63             NaN         -1600.0
#        S68             NaN         -1000.0
#        U11          2900.0             NaN
#        U96        100500.0             NaN
#        V03           600.0             NaN
#        Y92        851100.0             NaN
#        Z59         14200.0             NaN
#        Z74          6200.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 208195.17, short_sell_cash: 43725.06, borrow_cash: 0.00, net_value: 1123666.89
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       AU8U             NaN         -2500.0
#        BN4             NaN         -5800.0
#        BS6        213300.0             NaN
#       BUOU         17400.0             NaN
#        C09          6900.0             NaN
#       C38U         17600.0             NaN
#        C52         45100.0             NaN
#        C6L           700.0             NaN
#        CC3          2600.0             NaN
#        D05          1100.0             NaN
#        G13         78900.0             NaN
#       N2IU          3100.0             NaN
#        O39          1600.0             NaN
#        S63         14600.0             NaN
#        S68         32800.0             NaN
#        U96             NaN         -8500.0
#        V03          3000.0             NaN
#        Y92      32163600.0             NaN
#        Z74          2100.0             NaN
#
# 第6周：2019-02-11
# Smart Retail Flow FT5009 Portfolio cash: 329255.78, short_sell_cash: 35785.26, borrow_cash: 0.00, net_value: 939228.67
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5GD             NaN         -6100.0
#        BN2          6800.0             NaN
#        BN4         45800.0             NaN
#        BS6          5700.0             NaN
#        C07           100.0             NaN
#        C09             NaN          -300.0
#        C52          1400.0             NaN
#        C6L             NaN          -700.0
#        CC3          6600.0             NaN
#       CJLU          5600.0             NaN
#        D05         12100.0             NaN
#        E5H         28300.0             NaN
#        G13          7900.0             NaN
#       K71U             NaN         -2000.0
#        O39          5000.0             NaN
#        S58             NaN         -1600.0
#        S59          1800.0             NaN
#        S63             NaN         -2300.0
#        S68             NaN         -1800.0
#        U11          2900.0             NaN
#        U96        100500.0             NaN
#        V03           500.0             NaN
#        Y92             NaN        -42900.0
#        Z59         14200.0             NaN
#        Z74          9700.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 215526.86, short_sell_cash: 53033.21, borrow_cash: 0.00, net_value: 1311529.63
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN2             NaN         -7500.0
#        BS6        205400.0             NaN
#       BUOU         17400.0             NaN
#        C07             NaN          -400.0
#        C09          7300.0             NaN
#       C38U         17600.0             NaN
#        C52         43500.0             NaN
#        C6L          1100.0             NaN
#        CC3             NaN         -5400.0
#       CJLU             NaN         -7000.0
#        D05          1600.0             NaN
#        G13         74000.0             NaN
#       K71U          2800.0             NaN
#       N2IU          3100.0             NaN
#        O39          1600.0             NaN
#        Q5T             NaN         -9100.0
#        S58          1300.0             NaN
#        S59             NaN         -2200.0
#        S63         14600.0             NaN
#        S68         34300.0             NaN
#        U11           200.0             NaN
#        Y92      32954500.0             NaN
#        Z74          2100.0             NaN
#
# 第7周：2019-02-18
# Smart Retail Flow FT5009 Portfolio cash: 315222.17, short_sell_cash: 22976.65, borrow_cash: 0.00, net_value: 949054.90
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN2          6800.0             NaN
#        BN4         41500.0             NaN
#        BS6             NaN         -2300.0
#        BSL           600.0             NaN
#        C07           100.0             NaN
#        C09           100.0             NaN
#        C52          1400.0             NaN
#        C6L             NaN         -1600.0
#        CC3         13200.0             NaN
#       CJLU          5600.0             NaN
#        D05         12100.0             NaN
#        G13         12000.0             NaN
#        O39          7300.0             NaN
#        S58             NaN          -700.0
#        S59          1800.0             NaN
#        S68             NaN         -1400.0
#        U11          3700.0             NaN
#        U96         96700.0             NaN
#        V03           700.0             NaN
#        Z74          6100.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 387613.21, short_sell_cash: 36231.34, borrow_cash: 0.00, net_value: 1374536.40
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN4          5200.0             NaN
#        BS6        212100.0             NaN
#        C09          7100.0             NaN
#        C6L          3100.0             NaN
#        CC3             NaN         -3900.0
#        D05          1200.0             NaN
#       K71U          2800.0             NaN
#       N2IU          2600.0             NaN
#        O39             NaN          -500.0
#        S08          4500.0             NaN
#        S58          2600.0             NaN
#        S63         14600.0             NaN
#        S68         35400.0             NaN
#        U11             NaN          -400.0
#        V03             NaN          -100.0
#        Y92      32954500.0             NaN
#        Z74          4200.0             NaN
#
# 第8周：2019-02-25
# Smart Retail Flow FT5009 Portfolio cash: 391841.40, short_sell_cash: 35534.53, borrow_cash: 0.00, net_value: 952504.72
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        1D1          9300.0             NaN
#        AWX             NaN         -6800.0
#        BN2          6800.0             NaN
#        BN4         42500.0             NaN
#        BSL           600.0             NaN
#        C07           100.0             NaN
#        C09           500.0             NaN
#        CC3         14700.0             NaN
#       CJLU          5600.0             NaN
#        D05         11800.0             NaN
#        G13         20400.0             NaN
#       K71U             NaN         -1500.0
#        O39          9400.0             NaN
#        S58             NaN          -300.0
#        S59          1800.0             NaN
#        S63             NaN          -800.0
#        S68             NaN          -800.0
#        U11          4300.0             NaN
#        V03             NaN         -1100.0
#        Y92             NaN       -278300.0
#        Z74          6800.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 348792.34, short_sell_cash: 57389.29, borrow_cash: 0.00, net_value: 1388446.41
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        1D1             NaN         -9400.0
#        AWX          4800.0             NaN
#        BN4          4300.0             NaN
#        BS6        212100.0             NaN
#        C09          6700.0             NaN
#        C6L          3500.0             NaN
#        CC3             NaN         -1600.0
#        D05          1300.0             NaN
#        G13             NaN         -9900.0
#        H78           300.0             NaN
#       K71U          2800.0             NaN
#        O39             NaN         -1700.0
#        S08          4500.0             NaN
#        S58          2600.0             NaN
#        S63         15500.0             NaN
#        S68         36400.0             NaN
#       T82U          1300.0             NaN
#        U11             NaN          -600.0
#        V03          1800.0             NaN
#        Y92      33320600.0             NaN
#        Z74          3100.0             NaN
#
# 第9周：2019-03-04
# Smart Retail Flow FT5009 Portfolio cash: 509858.62, short_sell_cash: 62342.17, borrow_cash: 0.00, net_value: 946597.20
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        1D1          9300.0             NaN
#       AU8U             NaN         -5100.0
#        AWX             NaN         -6400.0
#        BN4         44800.0             NaN
#        BSL           600.0             NaN
#       BUOU             NaN        -13500.0
#        C07           100.0             NaN
#        C09           500.0             NaN
#        CC3         21400.0             NaN
#        D01           800.0             NaN
#        G13         26900.0             NaN
#       K71U             NaN         -9300.0
#       ME8U             NaN         -3100.0
#        O39         11500.0             NaN
#        S68             NaN         -4100.0
#        U11          5300.0             NaN
#        U14          1300.0             NaN
#        V03           400.0             NaN
#        Z74         14200.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 274490.19, short_sell_cash: 91865.33, borrow_cash: 0.00, net_value: 1377423.50
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U          2900.0             NaN
#       AU8U          4200.0             NaN
#       AW9U             NaN         -5700.0
#        AWX          9400.0             NaN
#        BN4          4300.0             NaN
#        BS6        212100.0             NaN
#        C09          7200.0             NaN
#       C38U             NaN         -3500.0
#        C52          6700.0             NaN
#        C6L          3500.0             NaN
#        CC3             NaN         -4100.0
#        D05          2900.0             NaN
#        G13             NaN        -11100.0
#        H78           300.0             NaN
#        J36             NaN          -100.0
#        O39             NaN         -1200.0
#        S08          4500.0             NaN
#        S58          2600.0             NaN
#        S63         15500.0             NaN
#        S68         39600.0             NaN
#       T82U          1300.0             NaN
#        U11             NaN          -700.0
#        U14             NaN         -1300.0
#        V03          2100.0             NaN
#        Y92      33320600.0             NaN
#        Z74             NaN         -5300.0
#
# 第10周：2019-03-11
# Smart Retail Flow FT5009 Portfolio cash: 446163.10, short_sell_cash: 69747.45, borrow_cash: 0.00, net_value: 942389.99
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        1D1          9300.0             NaN
#        544             NaN        -12000.0
#        A50             NaN        -88100.0
#       A7RU         12900.0             NaN
#        BN4         47300.0             NaN
#        BS6             NaN        -43300.0
#        C09           500.0             NaN
#       C38U          2300.0             NaN
#        C52             NaN         -2100.0
#        CC3         21400.0             NaN
#        D01          1400.0             NaN
#        F34             NaN         -2200.0
#        G13         26900.0             NaN
#        H78             NaN         -1000.0
#        O39         14000.0             NaN
#        S63             NaN         -2800.0
#        S68          4100.0             NaN
#        U11          5600.0             NaN
#        U14          1300.0             NaN
#        U96          4200.0             NaN
#        V03          1000.0             NaN
#        Y92             NaN       -809000.0
#        Z74          7300.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 242331.03, short_sell_cash: 73105.49, borrow_cash: 0.00, net_value: 1368821.92
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U          2900.0             NaN
#       AU8U          4200.0             NaN
#        AWX          9400.0             NaN
#        BS6        242000.0             NaN
#       BUOU         15700.0             NaN
#        C09          7200.0             NaN
#       C38U             NaN         -3900.0
#        C52          6700.0             NaN
#        C6L          3500.0             NaN
#        CC3             NaN         -4500.0
#        D01             NaN          -700.0
#        D05          2500.0             NaN
#        H78           300.0             NaN
#       K71U          9700.0             NaN
#       M44U         13000.0             NaN
#       N2IU         10800.0             NaN
#        O39             NaN         -3400.0
#        S63         19200.0             NaN
#        S68         37800.0             NaN
#       T82U          1300.0             NaN
#        U11             NaN          -300.0
#        U96             NaN         -3100.0
#        V03          1500.0             NaN
#        Y92      33320600.0             NaN
#        Z74          3900.0             NaN
#
# 第11周：2019-03-18
# Smart Retail Flow FT5009 Portfolio cash: 399235.22, short_sell_cash: 50187.56, borrow_cash: 0.00, net_value: 943178.61
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U             NaN         -1800.0
#       A7RU         12900.0             NaN
#       AW9U         20300.0             NaN
#        BN4         44000.0             NaN
#        BS6             NaN        -26700.0
#        C07           600.0             NaN
#       C38U             NaN          -200.0
#        C52             NaN         -5800.0
#        CC3         31700.0             NaN
#        D01          1400.0             NaN
#        D05             NaN          -700.0
#        G13         26900.0             NaN
#        H02           700.0             NaN
#        O39         12600.0             NaN
#        S20          4300.0             NaN
#        S68          6900.0             NaN
#        U11          5900.0             NaN
#        U14           100.0             NaN
#        U96          4200.0             NaN
#        V03          1000.0             NaN
#        Y92             NaN       -522300.0
#        Z74         11000.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 660597.26, short_sell_cash: 74818.50, borrow_cash: 0.00, net_value: 1379511.42
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U          2900.0             NaN
#       AU8U          4200.0             NaN
#        AWX          9400.0             NaN
#        BN4          1800.0             NaN
#        BS6        293300.0             NaN
#       BUOU         15700.0             NaN
#        C07             NaN          -300.0
#        C09          7700.0             NaN
#       C38U          3200.0             NaN
#        C52         11500.0             NaN
#        D01           800.0             NaN
#        D05          2500.0             NaN
#        F34             NaN         -1400.0
#        H78             NaN          -400.0
#       K71U         14200.0             NaN
#       M44U         13000.0             NaN
#       ME8U          3400.0             NaN
#       N2IU         10800.0             NaN
#        S63         17300.0             NaN
#        S68         36700.0             NaN
#        U11             NaN         -1100.0
#        U14          2100.0             NaN
#        V03          1900.0             NaN
#        Z74             NaN         -8100.0
#
# 第12周：2019-03-25
# Smart Retail Flow FT5009 Portfolio cash: 361019.39, short_sell_cash: 62285.31, borrow_cash: 0.00, net_value: 938632.62
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U             NaN         -4200.0
#       A7RU         44000.0             NaN
#       AW9U         20300.0             NaN
#        AWX          5900.0             NaN
#        BDX         43800.0             NaN
#        BN4         44000.0             NaN
#        C07           600.0             NaN
#        C52             NaN         -5000.0
#        C6L           900.0             NaN
#        CC3         35700.0             NaN
#       CJLU             NaN         -8000.0
#        D01           400.0             NaN
#        D05           200.0             NaN
#        H02           700.0             NaN
#       K71U             NaN         -8100.0
#        O39         16100.0             NaN
#        S20          4300.0             NaN
#        S68          8200.0             NaN
#        U11          6200.0             NaN
#        U14             NaN         -2400.0
#        U96          4200.0             NaN
#        V03          1000.0             NaN
#        Y92             NaN      -1253800.0
#        Z74          4400.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 864064.51, short_sell_cash: 83659.46, borrow_cash: 0.00, net_value: 1384982.96
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U          8300.0             NaN
#       A7RU             NaN        -27400.0
#        BDX             NaN        -44300.0
#        BN4          3800.0             NaN
#        BS6        293300.0             NaN
#       BUOU         15700.0             NaN
#        C09          7200.0             NaN
#       C38U           100.0             NaN
#        C52         16900.0             NaN
#        C6L             NaN          -900.0
#        D01          1800.0             NaN
#        H78             NaN          -800.0
#       K71U         19600.0             NaN
#       M44U         13000.0             NaN
#       ME8U          3400.0             NaN
#       N2IU         10800.0             NaN
#        O39             NaN         -4000.0
#        S63         15700.0             NaN
#        U14          4400.0             NaN
#        V03          2800.0             NaN
#        Y92        528600.0             NaN
#        Z74          5500.0             NaN
#
# 第13周：2019-04-01
# Smart Retail Flow FT5009 Portfolio cash: 462729.27, short_sell_cash: 29127.55, borrow_cash: 0.00, net_value: 947958.42
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A7RU         59300.0             NaN
#       AW9U         28400.0             NaN
#        AWX          8300.0             NaN
#        BDX         43800.0             NaN
#        BS6             NaN         -5900.0
#        C07           600.0             NaN
#        C6L           900.0             NaN
#        CC3         35700.0             NaN
#        D05             NaN         -1300.0
#        F34             NaN         -1100.0
#        G13         78100.0             NaN
#        H02           700.0             NaN
#       K71U          2100.0             NaN
#       N2IU          2100.0             NaN
#        O39         13400.0             NaN
#        OV8          2800.0             NaN
#        S20          4300.0             NaN
#        S68          8200.0             NaN
#       T82U          1100.0             NaN
#        U11          5600.0             NaN
#        Z74          1900.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 789366.15, short_sell_cash: 189022.36, borrow_cash: 0.00, net_value: 1398533.66
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U             NaN         -5600.0
#        BN4         13400.0             NaN
#        BS6        338700.0             NaN
#        C07           600.0             NaN
#        C09          7200.0             NaN
#       C38U             NaN         -6000.0
#        C52         10800.0             NaN
#        D01          1800.0             NaN
#        D05          1600.0             NaN
#        F34          3300.0             NaN
#        G13             NaN        -74600.0
#        J36           100.0             NaN
#       K71U         19600.0             NaN
#       ME8U          3400.0             NaN
#        O39          4400.0             NaN
#        S08         10900.0             NaN
#        S68             NaN         -1500.0
#       T82U             NaN        -10600.0
#        U11             NaN         -2600.0
#        U14          4400.0             NaN
#        U96         14300.0             NaN
#        V03          5100.0             NaN
#        Y92        528600.0             NaN
#        Z74             NaN         -2400.0
#
# 第14周：2019-04-08
# Smart Retail Flow FT5009 Portfolio cash: 343962.43, short_sell_cash: 146050.44, borrow_cash: 0.00, net_value: 949377.42
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A7RU         59300.0             NaN
#        AGS             NaN        -18100.0
#       AW9U        116100.0             NaN
#        AWX         22400.0             NaN
#        BDX         43800.0             NaN
#        BN4             NaN         -3800.0
#        C52             NaN         -6400.0
#        C6L           900.0             NaN
#        CC3         46700.0             NaN
#        D05             NaN          -900.0
#        F34             NaN         -7200.0
#        G13        191500.0             NaN
#       K71U          2100.0             NaN
#       N2IU          2100.0             NaN
#        O39          8000.0             NaN
#        OV8          2800.0             NaN
#        S58             NaN         -2500.0
#        S68         12300.0             NaN
#       T82U         11600.0             NaN
#        U11          4900.0             NaN
#        U14             NaN         -1500.0
#        V03           700.0             NaN
#        Z74             NaN        -20700.0
#
# Smart Insti Flow FT5009 Portfolio cash: 685562.88, short_sell_cash: 184400.85, borrow_cash: 0.00, net_value: 1420270.60
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5DM        115800.0             NaN
#        5GD         37600.0             NaN
#        AGS         55900.0             NaN
#       AW9U             NaN        -34100.0
#        BN4         13400.0             NaN
#        BS6        338700.0             NaN
#        C07           600.0             NaN
#        C52         10800.0             NaN
#        D01          1800.0             NaN
#        D05             NaN         -2000.0
#        F34          3300.0             NaN
#        G13             NaN        -44900.0
#        J36           400.0             NaN
#       K71U         19600.0             NaN
#       ME8U         14500.0             NaN
#        O39          1900.0             NaN
#       P40U         56600.0             NaN
#        S08         26800.0             NaN
#        S58          8000.0             NaN
#        S68             NaN         -3600.0
#       T82U             NaN        -10300.0
#        U11             NaN         -1700.0
#        U14          4400.0             NaN
#        U96         14300.0             NaN
#        V03          5100.0             NaN
#        Y92        528600.0             NaN
#        Z25         15400.0             NaN
#        Z74          7200.0             NaN
#
# 第15周：2019-04-15
# Smart Retail Flow FT5009 Portfolio cash: 323967.58, short_sell_cash: 173714.56, borrow_cash: 0.00, net_value: 941316.74
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5DM             NaN       -141400.0
#       A7RU         59300.0             NaN
#       AW9U        152700.0             NaN
#        AWX         33100.0             NaN
#        C07             NaN          -600.0
#        C09          2000.0             NaN
#       C38U         15100.0             NaN
#        CC3         46700.0             NaN
#        D05             NaN         -2700.0
#        F34             NaN         -8600.0
#        G13        240800.0             NaN
#       K71U          2100.0             NaN
#       N2IU         12300.0             NaN
#        OV8          2800.0             NaN
#        S63             NaN         -5700.0
#        S68         25500.0             NaN
#       T82U         19100.0             NaN
#        U14             NaN         -3000.0
#        V03             NaN         -1000.0
#        Z74             NaN         -4700.0
#
# Smart Insti Flow FT5009 Portfolio cash: 563533.63, short_sell_cash: 200694.65, borrow_cash: 0.00, net_value: 1421894.02
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5DM        316200.0             NaN
#        5GD         37600.0             NaN
#       A17U         17200.0             NaN
#        AGS         55900.0             NaN
#        BN4         13400.0             NaN
#        BS6        338700.0             NaN
#        C07          1100.0             NaN
#        C09             NaN         -1400.0
#       C38U             NaN        -13500.0
#        D05             NaN         -1000.0
#        F34         15800.0             NaN
#        G13             NaN        -31500.0
#        J36           600.0             NaN
#       ME8U         14500.0             NaN
#        O39             NaN         -2500.0
#       P40U         56600.0             NaN
#        S08         26800.0             NaN
#        S58          8000.0             NaN
#        S63          4600.0             NaN
#        S68             NaN         -6500.0
#        U11             NaN         -1800.0
#        U14         10700.0             NaN
#        U96         14300.0             NaN
#        V03          6500.0             NaN
#        Y92       1379600.0             NaN
#        Z25         15400.0             NaN
#        Z74             NaN          -300.0
#
# 第16周：2019-04-22
# Smart Retail Flow FT5009 Portfolio cash: 127350.84, short_sell_cash: 212852.24, borrow_cash: 0.00, net_value: 938755.76
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U             NaN         -4500.0
#       AW9U        152700.0             NaN
#        AWX         33100.0             NaN
#        BN4             NaN        -23900.0
#        C09          3100.0             NaN
#       C38U         15100.0             NaN
#        C52             NaN         -6800.0
#        C6L          2600.0             NaN
#        CC3         46700.0             NaN
#       CJLU             NaN        -15700.0
#        D05           600.0             NaN
#        F34             NaN         -4700.0
#        G13        251000.0             NaN
#       K71U         10400.0             NaN
#       N2IU         12300.0             NaN
#        O39             NaN         -3900.0
#        S63             NaN         -9700.0
#        S68         29700.0             NaN
#       T82U         48000.0             NaN
#        U11             NaN         -1300.0
#        U9E         32200.0             NaN
#        V03          6200.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 630701.92, short_sell_cash: 185275.92, borrow_cash: 0.00, net_value: 1429902.00
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5DM        316200.0             NaN
#        5GD         37600.0             NaN
#       A17U         14500.0             NaN
#        AGS         55900.0             NaN
#        BN4         39600.0             NaN
#        C07          1100.0             NaN
#        C09             NaN          -900.0
#        C6L             NaN         -2300.0
#       CJLU         16800.0             NaN
#        D05             NaN         -3500.0
#        F34         15800.0             NaN
#        G13             NaN        -21500.0
#        J36           800.0             NaN
#       K71U             NaN         -9200.0
#       M44U         16000.0             NaN
#       ME8U         14500.0             NaN
#        O39          1200.0             NaN
#       P40U         56600.0             NaN
#        S08         26800.0             NaN
#        S58          8000.0             NaN
#        S63         14300.0             NaN
#        S68             NaN         -3900.0
#       T82U             NaN        -15900.0
#        U11           900.0             NaN
#        U14         10700.0             NaN
#        V03          3400.0             NaN
#        Y92       3811700.0             NaN
#        Z25         15400.0             NaN
#        Z74             NaN         -2400.0
#
# 第17周：2019-04-29
# Smart Retail Flow FT5009 Portfolio cash: 156534.24, short_sell_cash: 19124.66, borrow_cash: 0.00, net_value: 934884.59
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       AW9U        152700.0             NaN
#        AWX         34300.0             NaN
#        BN4             NaN          -400.0
#        BS6          2100.0             NaN
#        BVQ          4300.0             NaN
#        C07           100.0             NaN
#        C09          3200.0             NaN
#       C38U         14500.0             NaN
#        C6L          2600.0             NaN
#        D05           400.0             NaN
#        G13        249100.0             NaN
#       K71U         10400.0             NaN
#       N2IU         11600.0             NaN
#        O39             NaN         -1500.0
#        OV8          2000.0             NaN
#        S63             NaN          -600.0
#        S68         29400.0             NaN
#       T82U         49100.0             NaN
#        U11           100.0             NaN
#        U9E         32200.0             NaN
#        V03          7300.0             NaN
#        Z74             NaN          -900.0
#
# Smart Insti Flow FT5009 Portfolio cash: 718322.90, short_sell_cash: 78220.41, borrow_cash: 0.00, net_value: 1429602.09
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5DM        316200.0             NaN
#       A17U         12100.0             NaN
#        AWX             NaN         -6500.0
#        BN4         41500.0             NaN
#        BS6             NaN        -44600.0
#        C07           600.0             NaN
#       C38U          8200.0             NaN
#        C52          3400.0             NaN
#       CJLU          5100.0             NaN
#        D05          2200.0             NaN
#        F34         15800.0             NaN
#        J36           800.0             NaN
#       M44U         22000.0             NaN
#       N2IU          4900.0             NaN
#        O39          6200.0             NaN
#        OV8             NaN         -6500.0
#        S58          9300.0             NaN
#        S63         16300.0             NaN
#        S68          2000.0             NaN
#       T82U             NaN         -4800.0
#        U11             NaN          -200.0
#        U14          9900.0             NaN
#        V03             NaN          -600.0
#        Y92       3811700.0             NaN
#
# 第18周：2019-05-06
# Smart Retail Flow FT5009 Portfolio cash: 149830.36, short_sell_cash: 124339.60, borrow_cash: 0.00, net_value: 927152.71
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        AWX         39900.0             NaN
#        BS6             NaN        -23000.0
#        BVQ          4300.0             NaN
#        C09          3900.0             NaN
#        C6L          2600.0             NaN
#        CC3             NaN         -5300.0
#        D05          2800.0             NaN
#        F34             NaN         -2800.0
#        G13        264700.0             NaN
#        H02             NaN          -600.0
#       K71U         10400.0             NaN
#       M44U             NaN         -7300.0
#        O39          3400.0             NaN
#        OV8             NaN         -6700.0
#        S63             NaN        -12000.0
#        S68         26400.0             NaN
#       T82U         53300.0             NaN
#        U11          1800.0             NaN
#        U9E         32200.0             NaN
#        V03          8600.0             NaN
#        Z74             NaN        -14500.0
#
# Smart Insti Flow FT5009 Portfolio cash: 808492.73, short_sell_cash: 111201.53, borrow_cash: 0.00, net_value: 1418358.98
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        AWX             NaN         -7800.0
#        BN4         41500.0             NaN
#        C07          1300.0             NaN
#        C09           800.0             NaN
#       C38U         16600.0             NaN
#        C52             NaN          -800.0
#       CJLU          5100.0             NaN
#        D05             NaN         -1000.0
#        J36           800.0             NaN
#       K71U          6400.0             NaN
#       M44U         22000.0             NaN
#       N2IU          4900.0             NaN
#        O39          4400.0             NaN
#        S58         10800.0             NaN
#        S63         26400.0             NaN
#        S68          4300.0             NaN
#       T82U             NaN         -5400.0
#        U11             NaN         -1100.0
#        V03             NaN         -2500.0
#        Y92       3811700.0             NaN
#        Z74         21100.0             NaN
#
# 第19周：2019-05-13
# Smart Retail Flow FT5009 Portfolio cash: 180370.13, short_sell_cash: 105689.01, borrow_cash: 0.00, net_value: 893914.76
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        AWX         39900.0             NaN
#        BN4          2800.0             NaN
#       BUOU             NaN        -13600.0
#        BVQ          4300.0             NaN
#        C09          4600.0             NaN
#        C6L          5100.0             NaN
#        D05          4600.0             NaN
#        E28             NaN        -15100.0
#        F34             NaN         -8300.0
#        G13        289800.0             NaN
#        H02             NaN         -1400.0
#        J36           100.0             NaN
#        O39          6900.0             NaN
#        OV8             NaN        -18900.0
#        S63             NaN         -9600.0
#       T82U         53300.0             NaN
#        U11          3000.0             NaN
#        V03          8600.0             NaN
#        Y92        592200.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 801900.05, short_sell_cash: 99360.20, borrow_cash: 0.00, net_value: 1416912.40
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN4         36800.0             NaN
#        C07          1500.0             NaN
#        C09             NaN         -1000.0
#       C38U         16600.0             NaN
#        C6L             NaN         -2300.0
#        D05          2300.0             NaN
#        F34         11600.0             NaN
#        G13             NaN        -47700.0
#        H02           700.0             NaN
#       K71U          6400.0             NaN
#       M44U         22000.0             NaN
#       N2IU          4900.0             NaN
#        O39          2300.0             NaN
#        OV8          9900.0             NaN
#        S58          8700.0             NaN
#        S63         23900.0             NaN
#        S68          4300.0             NaN
#        U11             NaN          -800.0
#        U96          6000.0             NaN
#        Z74         41300.0             NaN
#
# 第20周：2019-05-20
# Smart Retail Flow FT5009 Portfolio cash: 33356.48, short_sell_cash: 149163.88, borrow_cash: 0.00, net_value: 890503.72
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       AJBU             NaN         -6500.0
#        AWX         39900.0             NaN
#        BN4          7300.0             NaN
#        BS6             NaN        -42000.0
#        C09          5900.0             NaN
#       C2PU             NaN         -2600.0
#        C6L          8700.0             NaN
#        D05          6600.0             NaN
#        G13        289800.0             NaN
#        H02             NaN          -500.0
#        J36           100.0             NaN
#       J91U             NaN        -24600.0
#       ME8U             NaN         -3800.0
#        O39         10400.0             NaN
#        OV8             NaN         -6400.0
#        S68             NaN        -13100.0
#       T82U         53300.0             NaN
#        U11          4700.0             NaN
#        U96          5500.0             NaN
#        V03          9100.0             NaN
#        Y92             NaN       -364000.0
#
# Smart Insti Flow FT5009 Portfolio cash: 829258.44, short_sell_cash: 118413.83, borrow_cash: 0.00, net_value: 1415468.06
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U          6800.0             NaN
#        C07          1800.0             NaN
#        C09             NaN         -4500.0
#       C38U         16600.0             NaN
#        C52          4300.0             NaN
#        C6L             NaN         -5400.0
#        D05           900.0             NaN
#        F34          5500.0             NaN
#        H02           700.0             NaN
#        J36             NaN          -100.0
#       K71U          6400.0             NaN
#       N2IU             NaN         -1300.0
#        O39          5100.0             NaN
#        OV8          9900.0             NaN
#        S58          8700.0             NaN
#        S63         23900.0             NaN
#        S68          9400.0             NaN
#       T82U          7800.0             NaN
#        U11          1100.0             NaN
#        U96          6000.0             NaN
#        V03             NaN         -1000.0
#        Y92        690700.0             NaN
#        Z25             NaN         -6400.0
#        Z74         52200.0             NaN
#
# 第21周：2019-05-27
# Smart Retail Flow FT5009 Portfolio cash: 127695.25, short_sell_cash: 5750.17, borrow_cash: 0.00, net_value: 874890.72
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        BN4          7400.0             NaN
#        C09          5900.0             NaN
#        C6L          8700.0             NaN
#       CJLU             NaN         -1000.0
#        D05          6700.0             NaN
#        G13        290000.0             NaN
#        J36           100.0             NaN
#       ME8U             NaN          -300.0
#        O39         10600.0             NaN
#        OV8             NaN          -500.0
#        U11          4800.0             NaN
#        U96          5600.0             NaN
#        V03          9100.0             NaN
#        Y92             NaN        -49800.0
#        Z74             NaN         -1300.0
#
# Smart Insti Flow FT5009 Portfolio cash: 795777.74, short_sell_cash: 140088.96, borrow_cash: 0.00, net_value: 1419786.32
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U          2300.0             NaN
#        BS6         15800.0             NaN
#        C07          2100.0             NaN
#        C09          1400.0             NaN
#        C52         13200.0             NaN
#        C6L             NaN         -1600.0
#        CC3             NaN         -4800.0
#        D05             NaN          -300.0
#        F34          5500.0             NaN
#        H02           700.0             NaN
#        H78             NaN         -3600.0
#        J36           500.0             NaN
#        O39           300.0             NaN
#        OV8          9900.0             NaN
#        S63         37300.0             NaN
#        S68         12500.0             NaN
#       T82U          3300.0             NaN
#        U11             NaN         -3100.0
#        U14             NaN         -2000.0
#        U96          6000.0             NaN
#        V03          1100.0             NaN
#        Y92        690700.0             NaN
#        Z74         74400.0             NaN
#
# 第22周：2019-06-03
# Smart Retail Flow FT5009 Portfolio cash: 2423.93, short_sell_cash: 205272.66, borrow_cash: 0.00, net_value: 858365.95
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#       A17U          1800.0             NaN
#        BN4         19500.0             NaN
#        C07             NaN          -300.0
#        C09          5900.0             NaN
#       C38U             NaN         -6700.0
#        C6L         10100.0             NaN
#        CC3          3200.0             NaN
#        D05          9700.0             NaN
#        G13        309400.0             NaN
#       K71U             NaN        -15500.0
#       M44U             NaN         -8900.0
#       N2IU             NaN        -11800.0
#        O39         18700.0             NaN
#        S58          2200.0             NaN
#        S63             NaN        -17200.0
#        U11           800.0             NaN
# ...
# Stock Code  Positive Units  Negative Units
#        5E2         58600.0             NaN
#        9CI          5800.0             NaN
#       A17U             NaN        -19800.0
#        BN4          3100.0             NaN
#       BUOU             NaN        -20400.0
#       C38U             NaN         -9400.0
#        C52          1900.0             NaN
#        C6L          2200.0             NaN
#        D05         12700.0             NaN
#        F34             NaN         -3700.0
#        G13         24900.0             NaN
#        H78             NaN         -1900.0
#       J69U             NaN        -13400.0
#       JYEU             NaN        -13000.0
#       ME8U             NaN         -5800.0
#       N2IU         19900.0             NaN
#        O39          9200.0             NaN
#        S58         60700.0             NaN
#        S63          1200.0             NaN
#        S68         31800.0             NaN
#       SK6U             NaN        -13200.0
#       T82U         14300.0             NaN
#        U11          5100.0             NaN
#        U96         12100.0             NaN
#        Z74        490700.0             NaN
#
# 第286周：2024-09-23
# Smart Retail Flow FT5009 Portfolio cash: 199963.95, short_sell_cash: 154869.00, borrow_cash: 1600000.00, net_value: -616139.47
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        544        132000.0             NaN
#        558        120300.0             NaN
#        5CP         17800.0             NaN
#        9CI             NaN         -9800.0
#       A17U           100.0             NaN
#        AP4         20400.0             NaN
#        BN4             NaN         -1500.0
#        BS6        118500.0             NaN
#        BSL          7300.0             NaN
#       BUOU           100.0             NaN
#        C09           400.0             NaN
#       C38U          5100.0             NaN
#        C52             NaN         -4900.0
#        C6L             NaN         -5700.0
#        D05          1400.0             NaN
#        F34         11100.0             NaN
#        G13             NaN        -18800.0
#       J69U          8900.0             NaN
#       M44U           100.0             NaN
#       ME8U           100.0             NaN
#       N2IU         17500.0             NaN
#       P40U          6600.0             NaN
#        S08          5200.0             NaN
#        S58          4900.0             NaN
#        S63          1000.0             NaN
#       SK6U         23100.0             NaN
#        U11             NaN          -700.0
#        U96             NaN         -5900.0
#        V03          2500.0             NaN
#        Z74          6900.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 661217.57, short_sell_cash: 514724.50, borrow_cash: 0.00, net_value: 4458756.88
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5E2         58600.0             NaN
#        9CI          9400.0             NaN
#       A17U          7000.0             NaN
#        BN4          5800.0             NaN
#        BS6             NaN        -11700.0
#        BSL             NaN         -3200.0
#       C38U         22900.0             NaN
#        C52          1900.0             NaN
#        C6L          3600.0             NaN
#        D05         11400.0             NaN
#        F34          4300.0             NaN
#       ME8U          3000.0             NaN
#       N2IU         37500.0             NaN
#        O39          7800.0             NaN
#        S58         59400.0             NaN
#        S63           600.0             NaN
#        S68         31500.0             NaN
#       T82U         25000.0             NaN
#        U11          4800.0             NaN
#        U96         16900.0             NaN
#        Y92             NaN         -6700.0
#        Z74        472800.0             NaN
#
# 第287周：2024-09-30
# Smart Retail Flow FT5009 Portfolio cash: 227587.96, short_sell_cash: 174496.38, borrow_cash: 1600000.00, net_value: -639156.26
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5CP         17800.0             NaN
#        5E2             NaN        -46100.0
#        9CI             NaN         -2100.0
#       A17U           100.0             NaN
#       A7RU          8300.0             NaN
#        AIY             NaN          -900.0
#        BN4             NaN         -1700.0
#        BS6        134000.0             NaN
#        BSL          7300.0             NaN
#       BUOU           100.0             NaN
#        C09           400.0             NaN
#       C38U          5100.0             NaN
#        C6L             NaN         -2900.0
#        D05          1700.0             NaN
#        F34         14100.0             NaN
#        G13             NaN        -11500.0
#        H78             NaN         -1300.0
#       J69U         15200.0             NaN
#       M44U           100.0             NaN
#       ME8U           100.0             NaN
#       N2IU         17500.0             NaN
#        O39          3800.0             NaN
#       O5RU          2800.0             NaN
#       P40U          6600.0             NaN
#        S08          5200.0             NaN
#        S58             NaN         -2200.0
#        S63          1000.0             NaN
#        S68             NaN         -1800.0
#       SK6U         23100.0             NaN
#        U11          1300.0             NaN
#        V03          2800.0             NaN
#        Y92          9900.0             NaN
#        YF8             NaN        -13400.0
#        Z74          6900.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 601558.43, short_sell_cash: 542279.10, borrow_cash: 0.00, net_value: 4430501.29
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5E2         84800.0             NaN
#        9CI         13700.0             NaN
#       A17U          7000.0             NaN
#       A7RU             NaN         -7800.0
#        BN4          7800.0             NaN
#        BS6             NaN         -6700.0
#       C38U         22900.0             NaN
#        C52             NaN         -1000.0
#        C6L          5100.0             NaN
#        D05         12000.0             NaN
#        F34          4300.0             NaN
#        G13         16700.0             NaN
#       J69U             NaN         -7700.0
#       M44U         11600.0             NaN
#       ME8U          3000.0             NaN
#       N2IU         46900.0             NaN
#        NIO             NaN          -500.0
#        O39          5000.0             NaN
#        S58         63300.0             NaN
#        S63           600.0             NaN
#        S68         33600.0             NaN
#       T82U         25000.0             NaN
#        U11          2700.0             NaN
#        U96         16900.0             NaN
#        V03             NaN          -400.0
#        Y92             NaN        -27000.0
#        Z74        467700.0             NaN
#
# 第288周：2024-10-07
# Smart Retail Flow FT5009 Portfolio cash: 141600.27, short_sell_cash: 123840.53, borrow_cash: 1600000.00, net_value: -642152.50
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5CP         17800.0             NaN
#        5E2             NaN        -13900.0
#        9CI          6300.0             NaN
#       A17U         11200.0             NaN
#       A7RU          8300.0             NaN
#        AIY             NaN         -3100.0
#       AJBU             NaN         -5000.0
#        BN4          2300.0             NaN
#        BS6        134000.0             NaN
#        BSL          7300.0             NaN
#       BUOU         12100.0             NaN
#        C07             NaN          -200.0
#        C09          5200.0             NaN
#        C6L          4500.0             NaN
#        D05             NaN          -300.0
#        F34         14100.0             NaN
#        H78             NaN         -2200.0
#       J69U         15200.0             NaN
#       M44U         13400.0             NaN
#        NO4             NaN         -7200.0
#        O39          3800.0             NaN
#       O5RU          2800.0             NaN
#        OV8             NaN         -3100.0
#       P40U          6600.0             NaN
#        S08          5200.0             NaN
#        S58          3700.0             NaN
#        S63          1000.0             NaN
#        S68             NaN         -1300.0
#        U11          1300.0             NaN
#        U96             NaN         -1800.0
#        V03          3800.0             NaN
#        Y92          9900.0             NaN
#        Z25         12800.0             NaN
#        Z74          6900.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 2106737.93, short_sell_cash: 540623.88, borrow_cash: 0.00, net_value: 4415336.00
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5E2         91300.0             NaN
#        9CI          9000.0             NaN
#       A17U           100.0             NaN
#        AIY          1800.0             NaN
#        BN4          6700.0             NaN
#        BS6             NaN        -13500.0
#       BUOU          5900.0             NaN
#       C38U         17300.0             NaN
#        C52             NaN         -5100.0
#        C6L          5100.0             NaN
#        D05         14400.0             NaN
#        F34          8700.0             NaN
#        G13         25900.0             NaN
#        H78          3900.0             NaN
#        J36             NaN          -300.0
#       M44U         11600.0             NaN
#       ME8U          3000.0             NaN
#       N2IU         41400.0             NaN
#        NO4         12000.0             NaN
#        S58         63300.0             NaN
#        S68         34300.0             NaN
#       T82U         25000.0             NaN
#        U96         18400.0             NaN
#        V03             NaN          -500.0
#
# 第289周：2024-10-14
# Smart Retail Flow FT5009 Portfolio cash: 168061.33, short_sell_cash: 13398.44, borrow_cash: 1600000.00, net_value: -657188.90
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5E2          4800.0             NaN
#        9CI          6300.0             NaN
#       A17U         11200.0             NaN
#       A7RU          8300.0             NaN
#        BN4          2800.0             NaN
#        BS6        131700.0             NaN
#       BUOU         12100.0             NaN
#        C09          5600.0             NaN
#        C6L          5100.0             NaN
#        D05             NaN          -300.0
#        E28          1800.0             NaN
#        F34         14500.0             NaN
#        G13          6700.0             NaN
#       J69U         15200.0             NaN
#       M44U         13400.0             NaN
#       N2IU          1400.0             NaN
#        NO4          3800.0             NaN
#        O39          3400.0             NaN
#       O5RU          2800.0             NaN
#        S58          3500.0             NaN
#        S68             NaN          -100.0
#        U11          1300.0             NaN
#        U96             NaN          -100.0
#        V03          3800.0             NaN
#        Y92          7900.0             NaN
#        Z25         12800.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 1903447.29, short_sell_cash: 725770.88, borrow_cash: 0.00, net_value: 4409801.75
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5E2         64900.0             NaN
#        9CI          9000.0             NaN
#       A17U             NaN        -16500.0
#        AIY          1800.0             NaN
#       AJBU          9900.0             NaN
#        BN4             NaN         -1900.0
#        BS6         52600.0             NaN
#       BUOU          5900.0             NaN
#       C38U             NaN         -9900.0
#        C52         13700.0             NaN
#        C6L             NaN         -4800.0
#        D05         16300.0             NaN
#        F34             NaN         -2700.0
#        G13             NaN        -60300.0
#        H78          3900.0             NaN
#       J69U          6200.0             NaN
#       M44U         11600.0             NaN
#       N2IU          1700.0             NaN
#        NO4             NaN        -47600.0
#        O39          9600.0             NaN
#        S58         69400.0             NaN
#        S68         36100.0             NaN
#        U11             NaN         -1300.0
#        U96         18400.0             NaN
#        Y92         87900.0             NaN
#        Z74          8500.0             NaN
#
# 第290周：2024-10-21
# Smart Retail Flow FT5009 Portfolio cash: 375494.02, short_sell_cash: 523793.64, borrow_cash: 1600000.00, net_value: -650795.68
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5E2         43400.0             NaN
#        5LY             NaN       -145000.0
#        9CI         14300.0             NaN
#       A17U         13900.0             NaN
#       AJBU             NaN        -36500.0
#        BVA             NaN        -26400.0
#        C07             NaN         -2900.0
#       C2PU          5800.0             NaN
#       C38U         16700.0             NaN
#        C6L          8000.0             NaN
#        D01             NaN        -12200.0
#        D05          3800.0             NaN
#        E3B             NaN        -38700.0
#        F34         14500.0             NaN
#       M44U         24200.0             NaN
#       N2IU         30400.0             NaN
#        NO4             NaN        -46100.0
#        O39             NaN         -2700.0
#        S58             NaN        -54300.0
#        S68             NaN         -2300.0
#        U96          4800.0             NaN
#
# Smart Insti Flow FT5009 Portfolio cash: 1714630.25, short_sell_cash: 671360.80, borrow_cash: 0.00, net_value: 4419555.66
# Combined Positions:
# Stock Code  Positive Units  Negative Units
#        5E2         49300.0             NaN
#        9CI             NaN         -3100.0
#       A17U             NaN        -12700.0
#        AIY          1800.0             NaN
#       AJBU         58900.0             NaN
#        BS6         66900.0             NaN
#       BUOU          5900.0             NaN
#        C07          3100.0             NaN
#       C38U             NaN        -30600.0
#        C52         13700.0             NaN
#        D01         13600.0             NaN
#        D05         11100.0             NaN
#        E3B         40400.0             NaN
#        H78          3900.0             NaN
#       J69U         14700.0             NaN
#       M44U             NaN         -8500.0
#       N2IU             NaN        -16100.0
#        O39          9600.0             NaN
#        OV8          8600.0             NaN
#        S58        113000.0             NaN
#        S68         36100.0             NaN
#        U11             NaN         -1400.0
#        U96         12900.0             NaN
#        Y92        146000.0             NaN
#        Z25         23900.0             NaN
#
# Retail Portfolio Final: {'cash': 375494.0195055868, 'short_sell_cash': 523793.63820240076, 'position_units': {'F34': 14500, 'M44U': 24200, 'C38U': 16700, 'D05': 3800, '5E2': 43400, 'C6L': 8000, 'N2IU': 30400, '9CI': 14300, 'A17U': 13900, 'U96': 4800, 'C2PU': 5800, 'S68': -2300, 'D01': -12200, 'BVA': -26400, 'O39': -2700, 'S58': -54300, 'AJBU': -36500, 'C07': -2900, 'NO4': -46100, 'E3B': -38700, '5LY': -145000}, 'holding_weeks': {'F34': 2, 'M44U': 1, 'C38U': 1, 'D05': 1, '5E2': 1, 'C6L': 1, 'N2IU': 1, '9CI': 1, 'A17U': 1, 'U96': 1, 'C2PU': 1}, 'net_value': -650795.6770981961, 'borrow_cash': 1600000}
# Institution Portfolio Final: {'cash': 1714630.2470144688, 'short_sell_cash': 671360.8026941379, 'position_units': {'S58': 113000, 'S68': 36100, 'D05': 11100, '5E2': 49300, 'U96': 12900, 'H78': 3900, 'BUOU': 5900, 'AIY': 1800, 'O39': 9600, 'J69U': 14700, 'BS6': 66900, 'C52': 13700, 'AJBU': 58900, 'Y92': 146000, 'C07': 3100, 'OV8': 8600, 'D01': 13600, 'Z25': 23900, 'E3B': 40400, 'M44U': -8500, 'N2IU': -16100, 'C38U': -30600, 'U11': -1400, '9CI': -3100, 'A17U': -12700}, 'holding_weeks': {'S58': 1, 'S68': 2, 'D05': 2, '5E2': 3, 'U96': 3, 'H78': 3, 'BUOU': 3, 'AIY': 3, 'O39': 2, 'J69U': 1, 'BS6': 1, 'C52': 2, 'AJBU': 1, 'Y92': 1, 'C07': 1, 'OV8': 1, 'D01': 1, 'Z25': 1, 'E3B': 1}, 'net_value': 4419555.661232028, 'borrow_cash': 0}
